# %% [markdown]
# <a href="https://colab.research.google.com/github/rahuldabbeta/Flipkkart-MacBook-Web-Scrapping/blob/main/Flipkart_MacBook_web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import the required Modules:**

# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# **See the structure of URL:**

# %%
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=1
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=2

# %%
base_url = 'https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page='

# %% [markdown]
# **Create List for store the Data**

# %%
pd_name = []
price =[]
ratings = []
warranty = []
ratingsno = []
reviewsno = []
features = []
for i in range(1,3):
  time.sleep(3)
  req = requests.get(base_url+str(i))
  soup = BeautifulSoup(req.text,'html')

  #product name
  pdt_name = soup.findAll('div',attrs={'class':'_4rR01T'})
  [pd_name.append(i.text) for i in pdt_name]

  #price
  p = soup.findAll('div',attrs={'class':'_30jeq3 _1_WHN1'})
  [price.append(i.text) for i in p]

  #ratings
  r = soup.findAll('div',attrs={'class':'gUuXy-'})
  [ratings.append(i.span.div.text) for i in r]

  #warranty
  wl = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  w = [i.findAll('li')[-1] for i in wl]
  [warranty.append(i.text) for i in w]

  #number of ratings and reviews
  a = soup.findAll('span',attrs={'class':'_2_R_DZ'})
  for i in a:
    a = i.text.split('&')
    ratingsno.append(a[0].split(" ")[0])
    reviewsno.append(a[1].split(" ")[0])

  #features
  prop = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  for i in prop:
    a = i.findAll('li')[0:-2]
    b =[i.text for i in a]
    features.append(','.join(b))

# %%
print('pd_name= ',len(pd_name))
print('price = ',len(price))
print('ratings = ',len(ratings))
print('warranty = ',len(warranty))
print('ratingsno =',len(ratingsno))
print('reviewsno = ',len(reviewsno))
print('features = ',len(features))
# Out:
# pd_name=  25
# price =  25
# ratings =  25
# warranty =  25
# ratingsno = 25
# reviewsno =  25
# features =  25

# %%
data = pd.DataFrame({'Product':pd_name,
                     'Price':price,
                     'Ratings':ratings,
                     'Warranty':warranty,
                     'No of Ratings':ratingsno,
                     'No of Reviews':reviewsno,
                     'Features':features})
data
# Out:
#                                               Product  ...                                           Features
# 0   APPLE MacBook Air M1 - (8 GB/512 GB SSD/Mac OS...  ...  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 1   APPLE MacBook Air M1 - (8 GB/512 GB SSD/Mac OS...  ...  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 2   APPLE MacBook Air Core i5 10th Gen - (8 GB/512...  ...  Intel Core i5 Processor (10th Gen),8 GB LPDDR4...
# 3   APPLE MacBook Air Core i5 10th Gen - (8 GB/256...  ...  Intel Core i5 Processor (10th Gen),8 GB LPDDR4...
# 4   APPLE MacBook Air Core i5 10th Gen - (8 GB/512...  ...  Intel Core i5 Processor (10th Gen),8 GB LPDDR4...
# 5   APPLE MacBook Air Core i3 10th Gen - (8 GB/256...  ...  Intel Core i3 Processor (10th Gen),8 GB LPDDR4...
# 6   APPLE MacBook Air M1 - (8 GB/256 GB SSD/Mac OS...  ...  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 7   APPLE MacBook Air M1 - (8 GB/512 GB SSD/Mac OS...  ...  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 8   APPLE MacBook Pro M1 - (8 GB/256 GB SSD/Mac OS...  ...  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 9   APPLE MacBook Pro M1 - (8 GB/512 GB SSD/Mac OS...  ...  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 10  APPLE MacBook Pro M1 - (8 GB/512 GB SSD/Mac OS...  ...  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 11  APPLE MacBook Pro Core i7 9th Gen - (16 GB/512...  ...  Intel Core i7 Processor (9th Gen),16 GB DDR4 R...
# 12  APPLE MacBook Pro M1 - (8 GB/256 GB SSD/Mac OS...  ...  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 13  APPLE MacBook Pro Core i9 9th Gen - (16 GB/1 T...  ...  Intel Core i9 Processor (9th Gen),16 GB DDR4 R...
# 14  APPLE MacBook Pro Core i9 9th Gen - (16 GB/1 T...  ...  Intel Core i9 Processor (9th Gen),16 GB DDR4 R...
# 15  APPLE MacBook Pro Core i7 9th Gen - (16 GB/512...  ...  Intel Core i7 Processor (9th Gen),16 GB DDR4 R...
# 16  APPLE MacBook Pro Core i5 8th Gen - (8 GB/512 ...  ...  Intel Core i5 Processor (8th Gen),8 GB DDR3 RA...
# 17  APPLE MacBook Pro with Touch Bar Core i5 10th ...  ...  Intel Core i5 Processor (10th Gen),16 GB LPDDR...
# 18  APPLE MacBook Pro with Touch Bar Core i5 8th G...  ...  Intel Core i5 Processor (8th Gen),8 GB LPDDR3 ...
# 19  APPLE MacBook Pro with Touch Bar Core i5 8th G...  ...  Intel Core i5 Processor (8th Gen),8 GB LPDDR3 ...
# 20  APPLE MacBook Pro with Touch Bar Core i5 10th ...  ...  Intel Core i5 Processor (10th Gen),16 GB LPDDR...
# 21  APPLE MacBook Pro with Touch Bar Core i5 10th ...  ...  Intel Core i5 Processor (10th Gen),16 GB LPDDR...
# 22  APPLE MacBook Pro with Touch Bar Core i5 10th ...  ...  Intel Core i5 Processor (10th Gen),16 GB LPDDR...
# 23  APPLE MacBook Pro Core i5 8th Gen - (8 GB/512 ...  ...  Intel Core i5 Processor (8th Gen),8 GB DDR3 RA...
# 24  APPLE MacBook Pro Core i5 8th Gen - (8 GB/256 ...  ...  Intel Core i5 Processor (8th Gen),8 GB DDR3 RA...
#
# [25 rows x 7 columns]

# %%
data.to_csv('Flipkart ECommerce.csv')
